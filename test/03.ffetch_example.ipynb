# %%
import pywarp

# %%
url = 'https://sandbox.senx.io/api/v0/fetch'
token = '<Your-read-token>'

# %%
df = pywarp.ffetch(url, token, '~.*{}', 'now', '-10', indexedByTimestamp=True)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#                    l:unit l:serial            l:.app  \
# ts
# 1697792621461327  celsius    48779  sandbox.tutorial
# 1697786471461327  celsius    48779  sandbox.tutorial
# 1697786441461327  celsius    48779  sandbox.tutorial
# 1697785451461327  celsius    48779  sandbox.tutorial
# 1697785421453309  celsius    48779  sandbox.tutorial
# ...                   ...      ...               ...
# 1697787351461327      NaN    48779  sandbox.tutorial
# 1697787291461327      NaN    48779  sandbox.tutorial
# 1697787231461327      NaN    48779  sandbox.tutorial
# 1697787171461327      NaN    48779  sandbox.tutorial
# 1697787111461327      NaN    48779  sandbox.tutorial
#
#                   value:room.temperature.10x  value:outside.temperature  \
# ts
# 1697792621461327                       211.0                       15.0
# 1697786471461327                       211.0                        NaN
# 1697786441461327                       212.0                        NaN
# 1697785451461327                       212.0                        NaN
# 1697785421453309                       212.0                        NaN
# ...                                      ...                        ...
# 1697787351461327                         NaN                        NaN
# 1697787291461327                         NaN                        NaN
# 1697787231461327                         NaN                        NaN
# 1697787171461327                         NaN                        NaN
# 1697787111461327                         NaN                        NaN
#
#                   value:sanitary.water.temperature.10x  \
# ts
# 1697792621461327                                 509.0
# 1697786471461327                                   NaN
# 1697786441461327                                   NaN
# 1697785451461327                                   NaN
# 1697785421453309                                   NaN
# ...                                                ...
# 1697787351461327                                   NaN
# 1697787291461327                                   NaN
# 1697787231461327                                   NaN
# 1697787171461327                                   NaN
# 1697787111461327                                   NaN
#
#                   value:sanitary.water.temperature  value:heater.setpoint.10x  \
# ts
# 1697792621461327                             509.0                      210.0
# 1697786471461327                               NaN                        NaN
# 1697786441461327                               NaN                        NaN
# 1697785451461327                               NaN                      210.0
# 1697785421453309                               NaN                      210.0
# ...                                            ...                        ...
# 1697787351461327                               NaN                        NaN
# 1697787291461327                               NaN                        NaN
# 1697787231461327                               NaN                        NaN
# 1697787171461327                               NaN                        NaN
# 1697787111461327                               NaN                        NaN
#
#                   value:heatpump.power  value:heatpump.kwh.total  \
# ts
# 1697792621461327                   NaN                       NaN
# 1697786471461327                   NaN                       NaN
# 1697786441461327                   NaN                       NaN
# 1697785451461327                   NaN                       NaN
# 1697785421453309                   NaN                       NaN
# ...                                ...                       ...
# 1697787351461327                   NaN                       NaN
# 1697787291461327                   NaN                       NaN
# 1697787231461327                   NaN                       NaN
# 1697787171461327                   NaN                       NaN
# 1697787111461327                   NaN                       NaN
#
#                   value:ventilation.kwh.total  value:watermeter.pulsecount
# ts
# 1697792621461327                          NaN                          NaN
# 1697786471461327                          NaN                          NaN
# 1697786441461327                          NaN                          NaN
# 1697785451461327                          NaN                          NaN
# 1697785421453309                          NaN                          NaN
# ...                                       ...                          ...
# 1697787351461327                          NaN                        173.0
# 1697787291461327                          NaN                        168.0
# 1697787231461327                          NaN                        162.0
# 1697787171461327                          NaN                        156.0
# 1697787111461327                          NaN                        150.0
#
# [81 rows x 12 columns]
