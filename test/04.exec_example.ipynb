# %%
import pywarp

# %%
url = 'https://sandbox.senx.io/api/v0/exec'

# %%
warpscript = """
'<Your-read-token>'
'token' STORE

[ $token '~.*' {} NOW -10 ] FETCH
"""

# %%
result = pywarp.exec(url, warpscript)

# %%
type(result)
# Out:
# list

# %%
result
# Out:
# [[{'c': 'room.temperature.10x',
#    'l': {'unit': 'celsius', 'serial': '48779', '.app': 'sandbox.tutorial'},
#    'a': {},
#    'la': 1700730690514,
#    'v': [[1697792621461327, 211],
#     [1697786471461327, 211],
#     [1697786441461327, 212],
#     [1697785451461327, 212],
#     [1697785421453309, 212],
#     [1697781861453309, 212],
#     [1697781831443844, 212],
#     [1697779891443844, 212],
#     [1697779871443844, 213],
#     [1697778251443844, 213]]},
#   {'c': 'outside.temperature',
#    'l': {'unit': 'degC', 'serial': '48779', '.app': 'sandbox.tutorial'},
#    'a': {},
#    'la': 1699613806507,
#    'v': [[1697792631461327, 15.0],
#     [1697792621461327, 15.0],
#     [1697792611461327, 15.100000000000001],
#     [1697792601461327, 15.0],
#     [1697792591461327, 15.100000000000001],
#     [1697792581461327, 15.100000000000001],
#     [1697792571461327, 15.0],
#     [1697792561461327, 15.100000000000001],
#     [1697792551461327, 15.0],
#     [1697792541461327, 15.0]]},
# ...
