# %%
import pywarp

# %%
url = 'https://sandbox.senx.io/api/v0/fetch'
token = '<Your-read-token>'

# %%
df = pywarp.fetch(url, token, '~.*{}', 'now', '-10')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#                     class                                             labels  \
# 0    room.temperature.10x  {'unit': 'celsius', 'serial': '48779', '.app':...
# 1    room.temperature.10x  {'unit': 'celsius', 'serial': '48779', '.app':...
# 2    room.temperature.10x  {'unit': 'celsius', 'serial': '48779', '.app':...
# 3    room.temperature.10x  {'unit': 'celsius', 'serial': '48779', '.app':...
# 4    room.temperature.10x  {'unit': 'celsius', 'serial': '48779', '.app':...
# ..                    ...                                                ...
# 95  watermeter.pulsecount    {'serial': '48779', '.app': 'sandbox.tutorial'}
# 96  watermeter.pulsecount    {'serial': '48779', '.app': 'sandbox.tutorial'}
# 97  watermeter.pulsecount    {'serial': '48779', '.app': 'sandbox.tutorial'}
# 98  watermeter.pulsecount    {'serial': '48779', '.app': 'sandbox.tutorial'}
# 99  watermeter.pulsecount    {'serial': '48779', '.app': 'sandbox.tutorial'}
#
# ...
